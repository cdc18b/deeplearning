# %% [markdown]
# # Homework 03: Learning Curves and Training Workflow
#
# **Points:** 85
#
# In this assignment, you will learn how to design, train, and evaluate neural networks by systematically exploring key design choices. Your focus will be on developing an effective **training workflow** — using learning curves and validation metrics to guide your decisions.
#
# We'll use the **Forest Cover Type (Covertype) dataset,** which has ~581k tabular records with 54 cartographic/topographic features (elevation, aspect, slope, soil and wilderness indicators) used to predict one of seven tree cover types in Colorado’s Roosevelt National Forest. It’s a large, mildly imbalanced multi-class benchmark commonly used to compare classical ML and deep learning on tabular data.
#
# We will start with a **baseline model** (two hidden layers of sizes 64 and 32), and gradually introduce and tune different hyperparameters. Each of the first five problems considers  different hyperparameter choices, and the last problem is your chance to use what you have learned to design your best model:
#
# 1. **Activation function** – Compare ReLU, sigmoid, and tanh to see which provides the best accuracy.
# 2. **Learning rate** – Explore a range of learning rates and identify which balances convergence speed and stability.
# 3. **Dropout** – Investigate how different dropout rates reduce overfitting and where they are most effective.
# 4. **L2 regularization** – Experiment with weight penalties to encourage simpler models and avoid memorization.
# 5. **Dropout + L2** – Combine both regularization techniques and study their interaction.
# 6. **Best model design** – Use all your insights to build and train your strongest model, with the option to try **learning rate scheduling** for further improvement.
#
# In this homework, you will use **early stopping** to select the "best" model at the epoch of **minimum validation loss**, and you will report the **validation accuracy** of that selected model as the primary measure of performance. Test accuracy is reported for reference but is not used for model selection.
#
# > **Note:** Throughout this homework, best always refers to the model selected by early stopping at the epoch of minimum validation loss. Do not report metrics from the final training epoch unless explicitly instructed.
#
# By the end of this homework, you will not only understand how different hyperparameters affect training and generalization, but also gain hands-on practice in building a disciplined workflow for model development.
#
# There are 10 graded problems, worth 8 points each, with 5 points for free if you complete the homework.

# %%
# Useful imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import time
import os

from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.utils import class_weight

import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Input,Dropout
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers.schedules import ExponentialDecay


from tensorflow.keras.datasets import fashion_mnist

# utility code

random_seed = 42

def format_hms(seconds):
    return time.strftime("%H:%M:%S", time.gmtime(seconds))

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Suppresses INFO and WARNING messages

# %%
# Utility function to plot learning curves and keep track of all results

# Call `print_results()` to see listing of all results logged so far


def plot_learning_curves(hist, title, verbose=True):
    
    val_losses = hist.history['val_loss']
    min_val_loss = min(val_losses)
    min_val_epoch = val_losses.index(min_val_loss)
    val_acc_at_min_loss = hist.history['val_accuracy'][min_val_epoch]

    epochs = range(1, len(val_losses) + 1)  # epoch numbers starting at 1

    fig, axs = plt.subplots(2, 1, figsize=(8, 8), sharex=True)

    # --- Loss Plot ---
    axs[0].plot(epochs, hist.history['loss'], label='train loss')
    axs[0].plot(epochs, hist.history['val_loss'], label='val loss')
    axs[0].scatter(min_val_epoch + 1, min_val_loss, color='red', marker='x', s=50, label='min val loss')
    axs[0].set_title(f'{title} - Categorical Cross-Entropy Loss')
    axs[0].set_ylabel('Loss')
    axs[0].legend()
    axs[0].grid(True)

    # --- Accuracy Plot ---
    axs[1].plot(epochs, hist.history['accuracy'], label='train acc')
    axs[1].plot(epochs, hist.history['val_accuracy'], label='val acc')
    axs[1].scatter(min_val_epoch + 1, val_acc_at_min_loss, color='red', marker='x', s=50, label='acc @ min val loss')
    axs[1].set_title(f'{title} - Accuracy')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()
    axs[1].grid(True)
    axs[1].set_ylim(0, 1.05)

    plt.tight_layout()
    plt.show()

    if verbose:
        print(f"Final Training Loss:            {hist.history['loss'][-1]:.4f}")
        print(f"Final Training Accuracy:        {hist.history['accuracy'][-1]:.4f}")
        print(f"Final Validation Loss:          {hist.history['val_loss'][-1]:.4f}")
        print(f"Final Validation Accuracy:      {hist.history['val_accuracy'][-1]:.4f}")
        print(f"Minimum Validation Loss:        {min_val_loss:.4f} (Epoch {min_val_epoch + 1})")
        print(f"Validation Accuracy @ Min Loss: {val_acc_at_min_loss:.4f}")

    results[title] = (val_acc_at_min_loss,min_val_epoch + 1)

results = {}

# %% [markdown]
# **The plotting function will record the validation accuracy for each experiment, using the plot title as key. The next function will print these out (see the last cell in the notebook).**
#
#
# In order to see all results, you must give a different plot title to each experiment.

# %%
def print_results():
    for title, (acc, ep) in sorted(results.items(), 
                                   key=lambda kv: kv[1][0],   # kv[1] is (acc, epoch); [0] is acc
                                   reverse=True
                                  ):
        print(f"{title:<40}\t{acc:.4f}")

# %% [markdown]
# ### Wrapper to train, display results, and run test set
#
# We assume multi-class classification, and allow setting various parameters for training.

# %%
# Uses globals X_train,y_train,X_val,y_val

def train_and_test(model, 
                   epochs        = 500,                   # Just needs to be bigger than early stop point
                   lr_schedule   = 0.001,                 # Adam default / 10 seems to work well for this dataset
                   optimizer     = "Adam",
                   title         = "Learning Curves",
                   batch_size    = 64,                     # experiments confirmed this was optimal with other parameters at default
                   use_early_stopping = True,
                   patience      = 10,                                       
                   min_delta     = 0.0001,                 
                   callbacks     = [],                     # for extra callbacks other than early stopping
                   verbose       = 0,
                   return_history = False
                  ):

    print(f"\n{title}\n")


    if optimizer == "Adam":
        opt = Adam(learning_rate=lr_schedule) 
    else:
        opt = optimizer
    
    #Compiling the model
    model.compile(optimizer=opt, 
                  loss="sparse_categorical_crossentropy", 
                  metrics=["accuracy"]
                 )

    early_stop = EarlyStopping(
        monitor='val_loss',
        patience=patience,
        min_delta=min_delta,
        restore_best_weights=True,               # this will mean that the model which produced the smallest validation loss will be returned
        verbose=verbose
    )
    

    if use_early_stopping:
        cbs=[early_stop] + callbacks
    else:
        cbs=callbacks

    # start timer
    start = time.time()
    
    # Fit the model with early stopping
    history = model.fit(X_train, y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(X_val, y_val),       # must use stratified validation set
                        callbacks=cbs,
                        verbose=verbose
                       )

    if use_early_stopping:
        best_epoch = early_stop.best_epoch
        best_acc   = history.history['val_accuracy'][best_epoch]
    else:
        best_epoch = np.argmax(history.history['val_accuracy'])
        best_acc   = history.history['val_accuracy'][best_epoch]
    
    # Plot training history
    plot_learning_curves(history, title=title)

    # Evaluate on test data
    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    
    print(f"\nTest Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_accuracy:.4f}")

    print(f"\nValidation-Test Gap (accuracy): {abs(best_acc - test_accuracy):.6f}")
    
    # Record end time and print execution time
    end = time.time()
    print(f"\nExecution Time: " + format_hms(end-start))

    if return_history:
        return history

# %% [markdown]
# ### Load the dataset and extract a stratified subset
#
# This data set is rather large (581,012 samples) and unbalanced, but for the purposes of this homework, we use a much smaller set, and select samples so that it is balanced.

# %%
# complete cell: load, balance, split into X_train/y_train/x_val/y_val/X_test/y_test, and standardize
from collections import Counter
from sklearn.datasets import fetch_covtype
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

# 1) load
x, y = fetch_covtype(return_X_y=True)  # y in {1..7}
print("full dataset shape:", x.shape)

# 2) build a perfectly balanced subset across 7 classes (no replacement)
classes, counts = np.unique(y, return_counts=True)
# min_count = counts.min()  # size of rarest class                         # You can modify this parameter to increase the size of the dataset, but above
min_count = 1000                                                           # counts.min() you'll produce an unbalanced set. 


rng = np.random.default_rng(42)

idx_list = []
for c in classes:
    c_idx = np.where(y == c)[0]
    chosen = rng.choice(c_idx, size=min_count, replace=False)
    idx_list.append(chosen)

idx_bal = np.concatenate(idx_list)
rng.shuffle(idx_bal)

X_sub = x[idx_bal]
y_sub = y[idx_bal] - 1  # relabel to {0..6} for keras
print("balanced subset shape:", X_sub.shape, "class counts:", dict(Counter(y_sub)))

# 3) stratified 60/20/20 split (train/val/test)
test_size = 0.20
val_size = 0.20  # of the whole dataset

X_trainval, X_test, y_trainval, y_test = train_test_split(
    X_sub, y_sub, test_size=test_size, random_state=random_seed, stratify=y_sub
)
val_size_rel = val_size / (1.0 - test_size)  # e.g., 0.20 / 0.80 = 0.25

X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval, test_size=val_size_rel, random_state=random_seed, stratify=y_trainval
)

# 4) standardize using train-only stats (float32 for tensorflow friendliness)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train).astype(np.float32)
X_val   = scaler.transform(X_val).astype(np.float32)
X_test  = scaler.transform(X_test).astype(np.float32)

# 5) quick sanity checks
def show_counts(name, y_arr):
    c = Counter(y_arr)
    total = sum(c.values())
    print(f"{name}: total={total}, per-class={dict(c)}")

print("shapes:", "X_train", X_train.shape, "X_val", X_val.shape, "X_test", X_test.shape)
show_counts("train", y_train)
show_counts("val  ", y_val)
show_counts("test ", y_test)

# you now have: X_train, y_train, X_val, y_val, X_test, y_test

# Looks like integer encoded multi-class, let's check and define the global n_classes

labels = np.unique(y_train)

n_classes = len(labels)

print("class labels:",labels)
# Out:
# full dataset shape: (581012, 54)
# balanced subset shape: (7000, 54) class counts: {np.int32(2): 1000, np.int32(0): 1000, np.int32(4): 1000, np.int32(5): 1000, np.int32(1): 1000, np.int32(3): 1000, np.int32(6): 1000}
# shapes: X_train (4200, 54) X_val (1400, 54) X_test (1400, 54)
# train: total=4200, per-class={np.int32(2): 600, np.int32(1): 600, np.int32(0): 600, np.int32(3): 600, np.int32(5): 600, np.int32(4): 600, np.int32(6): 600}
# val  : total=1400, per-class={np.int32(1): 200, np.int32(6): 200, np.int32(5): 200, np.int32(4): 200, np.int32(3): 200, np.int32(2): 200, np.int32(0): 200}
# test : total=1400, per-class={np.int32(0): 200, np.int32(6): 200, np.int32(2): 200, np.int32(3): 200, np.int32(4): 200, np.int32(5): 200, np.int32(1): 200}
# class labels: [0 1 2 3 4 5 6]

# %% [markdown]
# ## Prelude: Defining a model builder
#
# In order to facilitate our experimentation, we'll write a function which builds models according to specifications:
#
# - How many layers
# - How wide each layer is
# - How much dropout in each layer
# - How much L2 Regularization in each layer
#
# This is a fairly standard practice in ML, since the structure of simple models is fairly predictable and can be specified by a few hyperparameters.

# %%
# This function will build a multi-class classifier with dropout and L2 regularization.
# You must specify the number of input features, the number of classes, and a list of layer hyperparameters
# in the form  [ ...., (width, activation function, L2 lambda, dropout rate), .... ]

# Note that when adding dropout, this appears as a separate layer, but it has no parameters to be trained. 

def build_model(n_inputs,layer_list,n_classes):
    layers = [ Input(shape=(n_inputs,)) ]
    for (width,act,l2_lambda,dropout_rate) in layer_list:
        layers.append( Dense(width, activation=act, kernel_regularizer=regularizers.l2(l2_lambda)) )
        if dropout_rate > 0:
            layers.append( Dropout(dropout_rate) )
    layers.append( Dense(n_classes, activation='softmax') )
    return models.Sequential( layers )

# %% [markdown]
# **Example: To build the following model:**

# %%
model = models.Sequential(
   [
    Input(shape=(X_train.shape[1],)),                              
    Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.0)),              # 0.0 means no regularization applied; no dropout, so no Dropout layer necessary
    Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.3),
    Dense(n_classes, activation='softmax')
   ]
)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         3,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,831 (22.78 KB)
#  Trainable params: 5,831 (22.78 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **We call `build_model` as shown here:**

# %%
build_model(X_train.shape[1], [ (64,'relu',0.0,0.0), (32,'relu',0.001,0.3)], n_classes).summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │         3,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,831 (22.78 KB)
#  Trainable params: 5,831 (22.78 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# -------------------
#
#
#
# ### Baseline Model Architecture
#
# **Problems 1–5 will use the following baseline model structure,** implemented with the provided `build_model` function and trained using `train_and_test`:
#
# ```
# input → 64 → 32 → output
# ```
#
# * Two hidden layers of widths 64 and 32.
# * Activation function, dropout rate, and L2 regularization term (λ) will vary as specified in each problem.
# * **Early stopping** is always applied to select the model at the epoch of **minimum validation loss**.
# * We will report the **validation accuracy** of the selected model as the primary metric.

# %% [markdown]
# ### Problem One: Which Activation Function?
#
# In this problem, you will train the **baseline neural network** and investigate which activation function produces the best performance. The model you create will be the one saved by **early stopping** — that is, the epoch where validation loss is minimized.
#
# **Steps to follow:**
#
# * Use the provided functions `train_and_test` and `build_model` to create a model named **`model_baseline`**.
# * Train and evaluate this model using each of the following activation functions in the hidden layers:
#
#   * `relu`
#   * `sigmoid`
#   * `tanh`
# * Identify which activation function produces the **best validation accuracy** at the epoch of **minimum validation loss**.
# * Answer the graded questions.

# %%
relu_model = build_model(X_train.shape[1], [ (64,'relu',0.0,0.0), (32,'relu',0.0,0.0)], n_classes)
relu_history = train_and_test(relu_model, title="ReLU Activation", return_history=True)

sigmoid_model = build_model(X_train.shape[1], [ (64,'sigmoid',0.0,0.0), (32,'sigmoid',0.0,0.0)], n_classes)
sigmoid_history = train_and_test(sigmoid_model, title="Sigmoid Activation", return_history=True)

tanh_model = build_model(X_train.shape[1], [ (64,'tanh',0.0,0.0), (32,'tanh',0.0,0.0)], n_classes)
tanh_history = train_and_test(tanh_model, title="Tanh Activation", return_history=True)
# Out:
# ReLU Activation
# Final Training Loss:            0.3861
# Final Training Accuracy:        0.8445
# Final Validation Loss:          0.5877
# Final Validation Accuracy:      0.7643
# Minimum Validation Loss:        0.5778 (Epoch 45)
# Validation Accuracy @ Min Loss: 0.7693
#
# Test Loss: 0.5778
# Test Accuracy: 0.7621
#
# Validation-Test Gap (accuracy): 0.007143
#
# Execution Time: 00:00:03
#
# Sigmoid Activation
# Final Training Loss:            0.3891
# Final Training Accuracy:        0.8488
# Final Validation Loss:          0.5590
# Final Validation Accuracy:      0.7664
# Minimum Validation Loss:        0.5548 (Epoch 160)
# Validation Accuracy @ Min Loss: 0.7714
#
# Test Loss: 0.5522
# Test Accuracy: 0.7550
#
# Validation-Test Gap (accuracy): 0.016429
#
# Execution Time: 00:00:08
#
# Tanh Activation
# Final Training Loss:            0.3460
# Final Training Accuracy:        0.8700
# Final Validation Loss:          0.5722
# Final Validation Accuracy:      0.7793
# Minimum Validation Loss:        0.5660 (Epoch 57)
# Validation Accuracy @ Min Loss: 0.7821
#
# Test Loss: 0.5828
# Test Accuracy: 0.7536
#
# Validation-Test Gap (accuracy): 0.028571
#
# Execution Time: 00:00:03

# %% [markdown]
# ### Graded Questions

# %%
# Set a1a to the activation function which provided the best validation accuracy at the epoch of minimum validation loss

a1a = 2             # Replace with integer 0 (relu), 1 (sigmoid), or 2 (tanh)

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a1a = {a1a}')
# Out:
# a1a = 2

# %%
# Set a1b to the validation accuracy found by this best activation function

a1b = 0.7821             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a1b = {a1b:.4f}')
# Out:
# a1b = 0.7821

# %% [markdown]
# ### Problem Two: Finding the Right Learning Rate
#
# In this problem, you will continue working with the **baseline model** and determine which learning rate produces the best performance. As before, the model you evaluate should be the one saved by **early stopping** — the epoch where validation loss is minimized.
#
# **Steps to follow:**
#
# * Build and train the **baseline model** using the **activation function identified in Problem One**.
#
# * Train and evaluate this model using each of the following learning rates:
#
#   ```
#       [1e-3, 5e-4, 1e-4, 5e-5, 1e-5]
#   ```
#
# * Identify which learning rate produces the **best validation accuracy** at the epoch of **minimum validation loss**, within a maximum of **500 epochs**.
#
# * Answer the graded questions.
#
#
# **Note: Smaller learning rates will generally take more epochs to reach the optimal point, so some of these will not engage early stopping, but run the full 500 epochs.**

# %%
learning_rates = [0.001, 0.0005, 0.0001, 0.00005, 0.00001]

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 0.0, 0.0), (32, "tanh", 0.0, 0.0)],
    n_classes
)
history1e3 = train_and_test(
    model,
    lr_schedule=0.001,
    title="Learning Rate 0.001",
    return_history=True
)

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 0.0, 0.0), (32, "tanh", 0.0, 0.0)],
    n_classes
)
history5e4 = train_and_test(
    model,
    lr_schedule=0.0005,
    title="Learning Rate 0.0005",
    return_history=True
)

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 0.0, 0.0), (32, "tanh", 0.0, 0.0)],
    n_classes
)
history1e4 = train_and_test(
    model,
    lr_schedule=0.0001,
    title="Learning Rate 0.0001",
    return_history=True
)

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 0.0, 0.0), (32, "tanh", 0.0, 0.0)],
    n_classes
)
history5e5 = train_and_test(
    model,
    lr_schedule=0.00005,
    title="Learning Rate 0.00005",
    return_history=True
)

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 0.0, 0.0), (32, "tanh", 0.0, 0.0)],
    n_classes
)
history1e5 = train_and_test(
    model,
    lr_schedule=0.00001,
    title="Learning Rate 0.00001",
    return_history=True
)
# Out:
# Learning Rate 0.001
# Final Training Loss:            0.3558
# Final Training Accuracy:        0.8612
# Final Validation Loss:          0.5575
# Final Validation Accuracy:      0.7771
# Minimum Validation Loss:        0.5506 (Epoch 55)
# Validation Accuracy @ Min Loss: 0.7786
#
# Test Loss: 0.5656
# Test Accuracy: 0.7693
#
# Validation-Test Gap (accuracy): 0.009286
#
# Execution Time: 00:00:03
#
# Learning Rate 0.0005
# Final Training Loss:            0.3901
# Final Training Accuracy:        0.8476
# Final Validation Loss:          0.5500
# Final Validation Accuracy:      0.7714
# Minimum Validation Loss:        0.5484 (Epoch 96)
# Validation Accuracy @ Min Loss: 0.7793
#
# Test Loss: 0.5777
# Test Accuracy: 0.7579
#
# Validation-Test Gap (accuracy): 0.021429
#
# Execution Time: 00:00:05
#
# Learning Rate 0.0001
# Final Training Loss:            0.4341
# Final Training Accuracy:        0.8269
# Final Validation Loss:          0.5794
# Final Validation Accuracy:      0.7679
# Minimum Validation Loss:        0.5794 (Epoch 418)
# Validation Accuracy @ Min Loss: 0.7679
#
# Test Loss: 0.5830
# Test Accuracy: 0.7579
#
# Validation-Test Gap (accuracy): 0.010000
#
# Execution Time: 00:00:19
#
# Learning Rate 0.00005
# Final Training Loss:            0.5170
# Final Training Accuracy:        0.7993
# Final Validation Loss:          0.6066
# Final Validation Accuracy:      0.7521
# Minimum Validation Loss:        0.6066 (Epoch 500)
# Validation Accuracy @ Min Loss: 0.7521
#
# Test Loss: 0.6273
# Test Accuracy: 0.7429
#
# Validation-Test Gap (accuracy): 0.009286
#
# Execution Time: 00:00:23
#
# Learning Rate 0.00001
# Final Training Loss:            0.7591
# Final Training Accuracy:        0.6957
# Final Validation Loss:          0.7809
# Final Validation Accuracy:      0.6871
# Minimum Validation Loss:        0.7809 (Epoch 500)
# Validation Accuracy @ Min Loss: 0.6871
#
# Test Loss: 0.7948
# Test Accuracy: 0.6857
#
# Validation-Test Gap (accuracy): 0.001429
#
# Execution Time: 00:00:23

# %% [markdown]
# #### Graded Questions

# %%
# Set a2a to the learning rate which provided the best validation accuracy at the epoch of minimum validation loss
best_lr = 0.0005
a2a = 0.0005           # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a2a = {a2a:.6f}')
# Out:
# a2a = 0.000500

# %%
# Set a2b to the validation accuracy found by this best learning rate

a2b = 0.7793             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a2b = {a2b:.4f}')
# Out:
# a2b = 0.7793

# %% [markdown]
# ### Problem Three: Dropout
#
# In this problem, you will explore how **dropout** can help prevent overfitting in neural networks. There are no absolute rules, but some useful heuristics are:
#
# * Dropout typically works best in **later dense layers** (e.g., the second hidden layer of width 32) in the range **0.3–0.5**.
# * If applied to **earlier layers** (e.g., the first hidden layer), dropout should be smaller, typically **0.0–0.2** (where 0.0 means no dropout).
#
# **Steps to follow:**
#
# * Build and train the **baseline model** using the **activation function from Problem One** and the **learning rate from Problem Two**.
# * Investigate dropout in the ranges suggested, using increments of **0.1**.
# * Identify which dropout configuration produces the **best validation accuracy** at the epoch of **minimum validation loss**.
# * Answer the graded questions.

# %%
# Your code here. Add as many cells as you need. 
dropout_rates_64 = [0.0, 0.1, 0.2]
dropout_rates_32 = [0.3, 0.4, 0.5]

for dr64 in dropout_rates_64:
    for dr32 in dropout_rates_32:
        model = build_model(
            X_train.shape[1],
            [(64, "tanh", 0.0, dr64), (32, "tanh", 0.0, dr32)],
            n_classes
        )
        title = f"Dropout 64:{dr64} 32:{dr32}"
        train_and_test(
            model,
            lr_schedule=best_lr,
            title=title
        )
# Out:
# Dropout 64:0.0 32:0.3
# Final Training Loss:            0.5271
# Final Training Accuracy:        0.7829
# Final Validation Loss:          0.5836
# Final Validation Accuracy:      0.7614
# Minimum Validation Loss:        0.5826 (Epoch 90)
# Validation Accuracy @ Min Loss: 0.7586
#
# Test Loss: 0.6054
# Test Accuracy: 0.7536
#
# Validation-Test Gap (accuracy): 0.005000
#
# Execution Time: 00:00:05
#
# Dropout 64:0.0 32:0.4
# Final Training Loss:            0.5275
# Final Training Accuracy:        0.7852
# Final Validation Loss:          0.5814
# Final Validation Accuracy:      0.7657
# Minimum Validation Loss:        0.5782 (Epoch 120)
# Validation Accuracy @ Min Loss: 0.7707
#
# Test Loss: 0.6148
# Test Accuracy: 0.7621
#
# Validation-Test Gap (accuracy): 0.008571
#
# Execution Time: 00:00:06
#
# Dropout 64:0.0 32:0.5
# Final Training Loss:            0.5531
# Final Training Accuracy:        0.7783
# Final Validation Loss:          0.5923
# Final Validation Accuracy:      0.7500
# Minimum Validation Loss:        0.5904 (Epoch 110)
# Validation Accuracy @ Min Loss: 0.7514
#
# Test Loss: 0.6081
# Test Accuracy: 0.7564
#
# Validation-Test Gap (accuracy): 0.005000
#
# Execution Time: 00:00:06
#
# Dropout 64:0.1 32:0.3
# Final Training Loss:            0.5716
# Final Training Accuracy:        0.7726
# Final Validation Loss:          0.5641
# Final Validation Accuracy:      0.7714
# Minimum Validation Loss:        0.5615 (Epoch 166)
# Validation Accuracy @ Min Loss: 0.7736
#
# Test Loss: 0.6012
# Test Accuracy: 0.7464
#
# Validation-Test Gap (accuracy): 0.029286
#
# Execution Time: 00:00:08
#
# Dropout 64:0.1 32:0.4
# Final Training Loss:            0.5545
# Final Training Accuracy:        0.7752
# Final Validation Loss:          0.5619
# Final Validation Accuracy:      0.7650
# Minimum Validation Loss:        0.5591 (Epoch 234)
# Validation Accuracy @ Min Loss: 0.7721
#
# Test Loss: 0.5933
# Test Accuracy: 0.7479
#
# Validation-Test Gap (accuracy): 0.025714
#
# Execution Time: 00:00:12
#
# Dropout 64:0.1 32:0.5
# Final Training Loss:            0.6345
# Final Training Accuracy:        0.7486
# Final Validation Loss:          0.5919
# Final Validation Accuracy:      0.7643
# Minimum Validation Loss:        0.5906 (Epoch 155)
# Validation Accuracy @ Min Loss: 0.7643
#
# Test Loss: 0.6197
# Test Accuracy: 0.7486
#
# Validation-Test Gap (accuracy): 0.015714
#
# Execution Time: 00:00:08
#
# Dropout 64:0.2 32:0.3
# Final Training Loss:            0.6024
# Final Training Accuracy:        0.7512
# Final Validation Loss:          0.5725
# Final Validation Accuracy:      0.7664
# Minimum Validation Loss:        0.5677 (Epoch 188)
# Validation Accuracy @ Min Loss: 0.7707
#
# Test Loss: 0.6111
# Test Accuracy: 0.7479
#
# Validation-Test Gap (accuracy): 0.022857
#
# Execution Time: 00:00:10
#
# Dropout 64:0.2 32:0.4
# Final Training Loss:            0.6075
# Final Training Accuracy:        0.7490
# Final Validation Loss:          0.5680
# Final Validation Accuracy:      0.7686
# Minimum Validation Loss:        0.5664 (Epoch 237)
# Validation Accuracy @ Min Loss: 0.7707
#
# Test Loss: 0.5986
# Test Accuracy: 0.7614
#
# Validation-Test Gap (accuracy): 0.009286
#
# Execution Time: 00:00:13
#
# Dropout 64:0.2 32:0.5
# Final Training Loss:            0.6643
# Final Training Accuracy:        0.7312
# Final Validation Loss:          0.5892
# Final Validation Accuracy:      0.7536
# Minimum Validation Loss:        0.5882 (Epoch 201)
# Validation Accuracy @ Min Loss: 0.7543
#
# Test Loss: 0.6250
# Test Accuracy: 0.7421
#
# Validation-Test Gap (accuracy): 0.012143
#
# Execution Time: 00:00:11

# %%
# Set a3a to the pair (dropout_rate_64,dropout_rate_32) of dropout rates for the two hidden layers which provided the best 
# validation accuracy at the epoch of minimum validation loss
best_dr64 = 0.1
best_dr32 = 0.3
a3a = (0.1,0.3)             # Replace (0.0,0.0) with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a3a = {a3a}')
# Out:
# a3a = (0.1, 0.3)

# %%
# Set a3b to the validation accuracy found by this best pair of dropout rates

a3b = 0.7736             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a3b = {a3b:.4f}')
# Out:
# a3b = 0.7736

# %% [markdown]
# ### Problem Four: L2 Regularization
#
# In this problem, you will explore how **L2 regularization** (also called *weight decay*) can help prevent overfitting in neural networks. There are no absolute rules, but some useful heuristics are:
#
# * Start simple by using the **same λ in both hidden layers**, with values:
#
#   ```
#       1e-4, 1e-3, 1e-2
#   ```
#
# * If validation results suggest underfitting in the first layer or persistent overfitting in the later one, then try adjusting per layer, for example:
#
#   * First hidden layer: λ = 1e-4
#   * Second hidden layer: λ = 1e-3
#
# **Steps to follow:**
#
# * Build and train the **baseline model** using the **activation function from Problem One** and the **learning rate from Problem Two**, but **without dropout**.
# * Investigate at least the four cases suggested (three with the same λ and one with different λ values). You may also consider additional combinations.
# * Identify which configuration produces the **best validation accuracy** at the epoch of **minimum validation loss**.
# * Answer the graded questions.

# %%
# Your code here. Add as many cells as you need. 

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 1e-4, 0.0), (32, "tanh", 1e-4, 0.0)],
    n_classes
)
train_and_test(
    model,
    lr_schedule=best_lr,
    title="L2 64:1e-4 32:1e-4"
)

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 1e-3, 0.0), (32, "tanh", 1e-3, 0.0)],
    n_classes
)
train_and_test(
    model,
    lr_schedule=best_lr,
    title="L2 64:1e-3 32:1e-3"
)

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 1e-2, 0.0), (32, "tanh", 1e-2, 0.0)],
    n_classes
)
train_and_test(
    model,
    lr_schedule=best_lr,
    title="L2 64:1e-2 32:1e-2"
)

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 1e-4, 0.0), (32, "tanh", 1e-3, 0.0)],
    n_classes
)
train_and_test(
    model,
    lr_schedule=best_lr,
    title="L2 64:1e-4 32:1e-3"
)
# Out:
# L2 64:1e-4 32:1e-4
# Final Training Loss:            0.3595
# Final Training Accuracy:        0.8712
# Final Validation Loss:          0.5987
# Final Validation Accuracy:      0.7729
# Minimum Validation Loss:        0.5862 (Epoch 131)
# Validation Accuracy @ Min Loss: 0.7807
#
# Test Loss: 0.5957
# Test Accuracy: 0.7621
#
# Validation-Test Gap (accuracy): 0.018571
#
# Execution Time: 00:00:07
#
# L2 64:1e-3 32:1e-3
# Final Training Loss:            0.5582
# Final Training Accuracy:        0.8167
# Final Validation Loss:          0.6699
# Final Validation Accuracy:      0.7707
# Minimum Validation Loss:        0.6656 (Epoch 96)
# Validation Accuracy @ Min Loss: 0.7693
#
# Test Loss: 0.6900
# Test Accuracy: 0.7564
#
# Validation-Test Gap (accuracy): 0.012857
#
# Execution Time: 00:00:05
#
# L2 64:1e-2 32:1e-2
# Final Training Loss:            0.7950
# Final Training Accuracy:        0.7169
# Final Validation Loss:          0.8014
# Final Validation Accuracy:      0.7079
# Minimum Validation Loss:        0.8007 (Epoch 99)
# Validation Accuracy @ Min Loss: 0.7086
#
# Test Loss: 0.8230
# Test Accuracy: 0.7036
#
# Validation-Test Gap (accuracy): 0.005000
#
# Execution Time: 00:00:06
#
# L2 64:1e-4 32:1e-3
# Final Training Loss:            0.4510
# Final Training Accuracy:        0.8498
# Final Validation Loss:          0.6159
# Final Validation Accuracy:      0.7871
# Minimum Validation Loss:        0.6090 (Epoch 114)
# Validation Accuracy @ Min Loss: 0.7836
#
# Test Loss: 0.6247
# Test Accuracy: 0.7629
#
# Validation-Test Gap (accuracy): 0.020714
#
# Execution Time: 00:00:06

# %%
# Set a4a to the pair (L2_lambda_64,L2_lambda_32) of the L2 lambdas for the two hidden layers which provided the best 
# validation accuracy at the epoch of minimum validation loss
L2_lambda_64 = 1e-4
L2_lambda_32 = 1e-3
a4a = (1e-4, 1e-3)             # Replace (0.0,0.0) with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a4a = {a4a}')
# Out:
# a4a = (0.0001, 0.001)

# %%
# Set a4b to the validation accuracy found by this best pair of lambdas

a4b = 0.7836             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a4b = {a4b:.4f}')
# Out:
# a4b = 0.7836

# %% [markdown]
# ### Problem Five: Combining Dropout with L2 Regularization
#
# In this problem, you will explore how **dropout** and **L2 regularization** can work together to prevent overfitting. These two methods complement each other, but must be balanced carefully. A useful rule of thumb is:
#
# * If dropout is **high**, use a **smaller λ**.
# * If dropout is **low**, you can afford a **larger λ**.
#
# **Steps to follow:**
#
# * Build and train the **baseline model** using the **activation function from Problem One** and the **learning rate from Problem Two**.
# * Investigate combinations of dropout and L2:
#
#   * First, use the **dropout rate you identified in Problem Three** as a baseline.
#   * Then, add L2 to both hidden layers with values:
#
#     ```
#         1e-4, 1e-3, 1e-2
#     ```
#
#     while keeping dropout fixed.
#   * Finally, try **reducing dropout slightly** when L2 is added to see if performance improves.
#   * [Optional] You may wish to investigate other combinations not covered here; for example, promising but not optimal choices of dropout rates may provide overall better performance when combines with L2 Regulari
# * Identify which combination produces the **best validation accuracy** at the epoch of **minimum validation loss**.
# * Answer the graded questions.

# %%
# Your code here. Add as many cells as you need.
model = build_model(
    X_train.shape[1],
    [(64, "tanh", 0.0, 0.1), (32, "tanh", 0.0, 0.3)],
    n_classes
)
train_and_test(
    model,
    lr_schedule=best_lr,
    title="Baseline: Dropout 64:0.1 32:0.3"
)

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 0.0001, 0.1), (32, "tanh", 0.0001, 0.3)],
    n_classes
)
train_and_test(
    model,
    lr_schedule=best_lr,
    title="L2 64:0.0001 32:0.0001 + Dropout 64:0.1 32:0.3"
)

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 0.001, 0.1), (32, "tanh", 0.001, 0.3)],
    n_classes
)
train_and_test(
    model,
    lr_schedule=best_lr,
    title="L2 64:0.001 32:0.001 + Dropout 64:0.1 32:0.3"
)

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 0.01, 0.1), (32, "tanh", 0.01, 0.3)],
    n_classes
)
train_and_test(
    model,
    lr_schedule=best_lr,
    title="L2 64:0.01 32:0.01 + Dropout 64:0.1 32:0.3"
)

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 0.01, 0.1), (32, "tanh", 0.01, 0.2)],
    n_classes
)
train_and_test(
    model,
    lr_schedule=best_lr,
    title="L2 64:0.01 32:0.01 + Dropout 64:0.1 32:0.2"
)

model = build_model(
    X_train.shape[1],
    [(64, "tanh", 0.01, 0.0), (32, "tanh", 0.01, 0.1)],
    n_classes
)
train_and_test(
    model,
    lr_schedule=best_lr,
    title="L2 64:0.01 32:0.01 + Dropout 64:0.0 32:0.1"
)
# Out:
# Baseline: Dropout 64:0.1 32:0.3
# Final Training Loss:            0.5856
# Final Training Accuracy:        0.7638
# Final Validation Loss:          0.5794
# Final Validation Accuracy:      0.7614
# Minimum Validation Loss:        0.5749 (Epoch 131)
# Validation Accuracy @ Min Loss: 0.7657
#
# Test Loss: 0.6006
# Test Accuracy: 0.7543
#
# Validation-Test Gap (accuracy): 0.011429
#
# Execution Time: 00:00:07
#
# L2 64:0.0001 32:0.0001 + Dropout 64:0.1 32:0.3
# Final Training Loss:            0.5846
# Final Training Accuracy:        0.7702
# Final Validation Loss:          0.5915
# Final Validation Accuracy:      0.7636
# Minimum Validation Loss:        0.5870 (Epoch 183)
# Validation Accuracy @ Min Loss: 0.7693
#
# Test Loss: 0.6237
# Test Accuracy: 0.7579
#
# Validation-Test Gap (accuracy): 0.011429
#
# Execution Time: 00:00:10
#
# L2 64:0.001 32:0.001 + Dropout 64:0.1 32:0.3
# Final Training Loss:            0.7024
# Final Training Accuracy:        0.7400
# Final Validation Loss:          0.6704
# Final Validation Accuracy:      0.7436
# Minimum Validation Loss:        0.6701 (Epoch 136)
# Validation Accuracy @ Min Loss: 0.7536
#
# Test Loss: 0.6925
# Test Accuracy: 0.7450
#
# Validation-Test Gap (accuracy): 0.008571
#
# Execution Time: 00:00:07
#
# L2 64:0.01 32:0.01 + Dropout 64:0.1 32:0.3
# Final Training Loss:            0.8399
# Final Training Accuracy:        0.6881
# Final Validation Loss:          0.8003
# Final Validation Accuracy:      0.6936
# Minimum Validation Loss:        0.7995 (Epoch 150)
# Validation Accuracy @ Min Loss: 0.6936
#
# Test Loss: 0.8259
# Test Accuracy: 0.7050
#
# Validation-Test Gap (accuracy): 0.011429
#
# Execution Time: 00:00:08
#
# L2 64:0.01 32:0.01 + Dropout 64:0.1 32:0.2
# Final Training Loss:            0.8296
# Final Training Accuracy:        0.6974
# Final Validation Loss:          0.8021
# Final Validation Accuracy:      0.7014
# Minimum Validation Loss:        0.7977 (Epoch 158)
# Validation Accuracy @ Min Loss: 0.6964
#
# Test Loss: 0.8218
# Test Accuracy: 0.6950
#
# Validation-Test Gap (accuracy): 0.001429
#
# Execution Time: 00:00:08
#
# L2 64:0.01 32:0.01 + Dropout 64:0.0 32:0.1
# Final Training Loss:            0.7445
# Final Training Accuracy:        0.7355
# Final Validation Loss:          0.7552
# Final Validation Accuracy:      0.7314
# Minimum Validation Loss:        0.7547 (Epoch 211)
# Validation Accuracy @ Min Loss: 0.7264
#
# Test Loss: 0.7832
# Test Accuracy: 0.7264
#
# Validation-Test Gap (accuracy): 0.000000
#
# Execution Time: 00:00:11

# %%
# Set a5 to the validation accuracy found by this best combination of dropout and L2 regularization

a5 = 0.7693              # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a5 = {a5:.4f}')
# Out:
# a5 = 0.7693

# %% [markdown]
# ### Problem Six: Build and Train Your Best Model
#
# In this final problem, you will design and train your **best-performing model** using the techniques explored in the previous problems. You may make your own choices for:
#
# * **Model architecture** (number of layers, widths, etc.)
# * **Learning rate**
# * **Batch size** (a new hyperparameter not varied in earlier problems)
# * **Dropout rates** in both layers
# * **L2 λ values** in both layers
# * **[Optional but strongly suggested]:** Learning rate scheduling, using either **Exponential Decay** or **Cosine Decay**.
#
#   * For Exponential Decay, typical decay rates are **0.90–0.999**, with **0.95** often a good starting point.
#
# **Steps to follow:**
#
# * Build and train the model according to your design choices.
# * Use early stopping as before to evaluate performance at the epoch of **minimum validation loss**.
# * Answer the graded question.

# %%
candidate_combos = [
    {"nhl": 3, "width": 128, "lr": 0.001,  "bs": 64,  "dr": 0.2, "l2": 0.0001},
    {"nhl": 3, "width": 256, "lr": 0.001,  "bs": 64,  "dr": 0.3, "l2": 0.0001},
    {"nhl": 4, "width": 128, "lr": 0.001,  "bs": 64,  "dr": 0.3, "l2": 0.0001},
    {"nhl": 4, "width": 256, "lr": 0.001,  "bs": 64,  "dr": 0.4, "l2": 0.0001},

    {"nhl": 3, "width": 128, "lr": 0.0001, "bs": 64,  "dr": 0.1, "l2": 0.0001},
    {"nhl": 3, "width": 256, "lr": 0.0001, "bs": 64,  "dr": 0.2, "l2": 0.0001},
    {"nhl": 4, "width": 128, "lr": 0.0001, "bs": 64,  "dr": 0.2, "l2": 0.0001},
    {"nhl": 4, "width": 256, "lr": 0.0001, "bs": 64,  "dr": 0.3, "l2": 0.0001},

    {"nhl": 3, "width": 128, "lr": 0.001,  "bs": 128, "dr": 0.2, "l2": 0.001},
    {"nhl": 4, "width": 128, "lr": 0.001,  "bs": 128, "dr": 0.3, "l2": 0.001},
]

histories = []

for combo_index, combo in enumerate(candidate_combos, start=1):
    nhl = combo["nhl"]
    width = combo["width"]
    lr = combo["lr"]
    bs = combo["bs"]
    dr = combo["dr"]
    l2 = combo["l2"]

    layer_list = []
    for _ in range(nhl):
        layer_list.append((width, "tanh", l2, dr))

    model = build_model(X_train.shape[1], layer_list, n_classes)

    title = f"TRY {combo_index}/10 | NHL:{nhl} W:{width} LR:{lr} BS:{bs} DR:{dr} L2:{l2}"

    history = train_and_test(
        model,
        lr_schedule=lr,      # if your function uses "learning_rate" instead, swap this arg name
        batch_size=bs,
        title=title,
        return_history=True
    )

    histories.append((title, history))

best_acc = -1.0
best_title = ""
best_epoch = -1
best_min_val_loss = None

for title, history in histories:
    val_losses = history.history["val_loss"]
    min_val_epoch = int(np.argmin(val_losses))
    val_acc_at_min_loss = history.history["val_accuracy"][min_val_epoch]

    if val_acc_at_min_loss > best_acc:
        best_acc = val_acc_at_min_loss
        best_title = title
        best_epoch = min_val_epoch
        best_min_val_loss = val_losses[min_val_epoch]

print("Best model (by val_accuracy at min val_loss):")
print(best_title)
print(f"Best val_accuracy: {best_acc}")
print(f"Epoch of min val_loss: {best_epoch}")
print(f"Min val_loss: {best_min_val_loss}")
# Out:
# TRY 1/10 | NHL:3 W:128 LR:0.001 BS:64 DR:0.2 L2:0.0001
# Final Training Loss:            0.4776
# Final Training Accuracy:        0.8300
# Final Validation Loss:          0.5707
# Final Validation Accuracy:      0.7993
# Minimum Validation Loss:        0.5604 (Epoch 83)
# Validation Accuracy @ Min Loss: 0.7986
#
# Test Loss: 0.6005
# Test Accuracy: 0.7807
#
# Validation-Test Gap (accuracy): 0.017857
#
# Execution Time: 00:00:06
#
# TRY 2/10 | NHL:3 W:256 LR:0.001 BS:64 DR:0.3 L2:0.0001
# Final Training Loss:            0.5141
# Final Training Accuracy:        0.8329
# Final Validation Loss:          0.6006
# Final Validation Accuracy:      0.7986
# Minimum Validation Loss:        0.5807 (Epoch 65)
# Validation Accuracy @ Min Loss: 0.8000
#
# Test Loss: 0.6227
# Test Accuracy: 0.7864
#
# Validation-Test Gap (accuracy): 0.013571
#
# Execution Time: 00:00:08
#
# TRY 3/10 | NHL:4 W:128 LR:0.001 BS:64 DR:0.3 L2:0.0001
# Final Training Loss:            0.5948
# Final Training Accuracy:        0.7783
# Final Validation Loss:          0.5977
# Final Validation Accuracy:      0.7757
# Minimum Validation Loss:        0.5909 (Epoch 78)
# Validation Accuracy @ Min Loss: 0.7800
#
# Test Loss: 0.6502
# Test Accuracy: 0.7507
#
# Validation-Test Gap (accuracy): 0.029286
#
# Execution Time: 00:00:07
#
# TRY 4/10 | NHL:4 W:256 LR:0.001 BS:64 DR:0.4 L2:0.0001
# Final Training Loss:            0.5871
# Final Training Accuracy:        0.8045
# Final Validation Loss:          0.6367
# Final Validation Accuracy:      0.7950
# Minimum Validation Loss:        0.6190 (Epoch 94)
# Validation Accuracy @ Min Loss: 0.7907
#
# Test Loss: 0.6457
# Test Accuracy: 0.7793
#
# Validation-Test Gap (accuracy): 0.011429
#
# Execution Time: 00:00:15
#
# TRY 5/10 | NHL:3 W:128 LR:0.0001 BS:64 DR:0.1 L2:0.0001
# Final Training Loss:            0.5376
# Final Training Accuracy:        0.7943
# Final Validation Loss:          0.5933
# Final Validation Accuracy:      0.7786
# Minimum Validation Loss:        0.5927 (Epoch 229)
# Validation Accuracy @ Min Loss: 0.7707
#
# Test Loss: 0.6043
# Test Accuracy: 0.7586
#
# Validation-Test Gap (accuracy): 0.012143
#
# Execution Time: 00:00:16
#
# TRY 6/10 | NHL:3 W:256 LR:0.0001 BS:64 DR:0.2 L2:0.0001
# Final Training Loss:            0.5097
# Final Training Accuracy:        0.8219
# Final Validation Loss:          0.5876
# Final Validation Accuracy:      0.7836
# Minimum Validation Loss:        0.5840 (Epoch 248)
# Validation Accuracy @ Min Loss: 0.7886
#
# Test Loss: 0.6037
# Test Accuracy: 0.7771
#
# Validation-Test Gap (accuracy): 0.011429
#
# Execution Time: 00:00:32
#
# TRY 7/10 | NHL:4 W:128 LR:0.0001 BS:64 DR:0.2 L2:0.0001
# Final Training Loss:            0.6365
# Final Training Accuracy:        0.7455
# Final Validation Loss:          0.6095
# Final Validation Accuracy:      0.7636
# Minimum Validation Loss:        0.6072 (Epoch 243)
# Validation Accuracy @ Min Loss: 0.7686
#
# Test Loss: 0.6390
# Test Accuracy: 0.7507
#
# Validation-Test Gap (accuracy): 0.017857
#
# Execution Time: 00:00:20
#
# TRY 8/10 | NHL:4 W:256 LR:0.0001 BS:64 DR:0.3 L2:0.0001
# Final Training Loss:            0.6660
# Final Training Accuracy:        0.7567
# Final Validation Loss:          0.6544
# Final Validation Accuracy:      0.7650
# Minimum Validation Loss:        0.6512 (Epoch 184)
# Validation Accuracy @ Min Loss: 0.7643
#
# Test Loss: 0.6813
# Test Accuracy: 0.7457
#
# Validation-Test Gap (accuracy): 0.018571
#
# Execution Time: 00:00:30
#
# TRY 9/10 | NHL:3 W:128 LR:0.001 BS:128 DR:0.2 L2:0.001
# Final Training Loss:            0.7209
# Final Training Accuracy:        0.7448
# Final Validation Loss:          0.6979
# Final Validation Accuracy:      0.7586
# Minimum Validation Loss:        0.6969 (Epoch 87)
# Validation Accuracy @ Min Loss: 0.7579
#
# Test Loss: 0.7282
# Test Accuracy: 0.7379
#
# Validation-Test Gap (accuracy): 0.020000
#
# Execution Time: 00:00:06
#
# TRY 10/10 | NHL:4 W:128 LR:0.001 BS:128 DR:0.3 L2:0.001
# Final Training Loss:            0.7748
# Final Training Accuracy:        0.7210
# Final Validation Loss:          0.7349
# Final Validation Accuracy:      0.7314
# Minimum Validation Loss:        0.7205 (Epoch 100)
# Validation Accuracy @ Min Loss: 0.7350
#
# Test Loss: 0.7493
# Test Accuracy: 0.7336
#
# Validation-Test Gap (accuracy): 0.001429
#
# Execution Time: 00:00:08
# Best model (by val_accuracy at min val_loss):
# TRY 2/10 | NHL:3 W:256 LR:0.001 BS:64 DR:0.3 L2:0.0001
# Best val_accuracy: 0.800000011920929
# Epoch of min val_loss: 64
# Min val_loss: 0.5806949138641357

# %%
# Set a6 to the validation accuracy found by this best model

a6 = 0.8000             # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way          

print(f'a6 = {a6:.4f}')
# Out:
# a6 = 0.8000

# %% [markdown]
# ### Optional: Print out your results of all experiments

# %%
print_results()
# Out:
# TRY 2/10 | NHL:3 W:256 LR:0.001 BS:64 DR:0.3 L2:0.0001	0.8000
# TRY 1/10 | NHL:3 W:128 LR:0.001 BS:64 DR:0.2 L2:0.0001	0.7986
# TRY 4/10 | NHL:4 W:256 LR:0.001 BS:64 DR:0.4 L2:0.0001	0.7907
# TRY 6/10 | NHL:3 W:256 LR:0.0001 BS:64 DR:0.2 L2:0.0001	0.7886
# L2 64:1e-4 32:1e-3                      	0.7836
# Tanh Activation                         	0.7821
# NHL:2 W:64 LR:0.01 BS:32 DR:0.1 L2:0.0  	0.7814
# L2 64:1e-4 32:1e-4                      	0.7807
# TRY 3/10 | NHL:4 W:128 LR:0.001 BS:64 DR:0.3 L2:0.0001	0.7800
# Learning Rate 0.0005                    	0.7793
# Learning Rate 0.001                     	0.7786
# Dropout 64:0.1 32:0.3                   	0.7736
# Dropout 64:0.1 32:0.4                   	0.7721
# Sigmoid Activation                      	0.7714
# NHL:2 W:64 LR:0.01 BS:32 DR:0.2 L2:0.0  	0.7714
# Dropout 64:0.0 32:0.4                   	0.7707
# Dropout 64:0.2 32:0.3                   	0.7707
# Dropout 64:0.2 32:0.4                   	0.7707
# TRY 5/10 | NHL:3 W:128 LR:0.0001 BS:64 DR:0.1 L2:0.0001	0.7707
# ReLU Activation                         	0.7693
# L2 64:1e-3 32:1e-3                      	0.7693
# L2 64:0.0001 32:0.0001 + Dropout 64:0.1 32:0.3	0.7693
# NHL:2 W:128 LR:0.01 BS:32 DR:0.0 L2:0.0 	0.7693
# TRY 7/10 | NHL:4 W:128 LR:0.0001 BS:64 DR:0.2 L2:0.0001	0.7686
# Learning Rate 0.0001                    	0.7679
# NHL:2 W:128 LR:0.01 BS:32 DR:0.2 L2:0.0 	0.7679
# Baseline: Dropout 64:0.1 32:0.3         	0.7657
# Dropout 64:0.1 32:0.5                   	0.7643
# TRY 8/10 | NHL:4 W:256 LR:0.0001 BS:64 DR:0.3 L2:0.0001	0.7643
# NHL:2 W:32 LR:0.01 BS:32 DR:0.0 L2:0.0  	0.7636
# NHL:2 W:32 LR:0.01 BS:32 DR:0.2 L2:0.0001	0.7636
# NHL:2 W:128 LR:0.01 BS:32 DR:0.1 L2:0.0 	0.7621
# NHL:2 W:64 LR:0.01 BS:32 DR:0.3 L2:0.0  	0.7600
# NHL:2 W:64 LR:0.01 BS:32 DR:0.4 L2:0.0  	0.7593
# Dropout 64:0.0 32:0.3                   	0.7586
# NHL:2 W:32 LR:0.01 BS:32 DR:0.3 L2:0.0  	0.7586
# NHL:2 W:64 LR:0.01 BS:32 DR:0.0 L2:0.0  	0.7579
# TRY 9/10 | NHL:3 W:128 LR:0.001 BS:128 DR:0.2 L2:0.001	0.7579
# Dropout 64:0.2 32:0.5                   	0.7543
# L2 64:0.001 32:0.001 + Dropout 64:0.1 32:0.3	0.7536
# NHL:2 W:32 LR:0.01 BS:32 DR:0.1 L2:0.0  	0.7536
# Learning Rate 0.00005                   	0.7521
# Dropout 64:0.0 32:0.5                   	0.7514
# NHL:2 W:32 LR:0.01 BS:32 DR:0.0 L2:0.0001	0.7507
# NHL:2 W:64 LR:0.01 BS:32 DR:0.2 L2:0.0001	0.7507
# NHL:2 W:64 LR:0.01 BS:32 DR:0.1 L2:0.0001	0.7486
# NHL:2 W:128 LR:0.01 BS:32 DR:0.3 L2:0.0 	0.7479
# NHL:2 W:64 LR:0.01 BS:32 DR:0.0 L2:0.001	0.7464
# NHL:2 W:256 LR:0.01 BS:32 DR:0.1 L2:0.0 	0.7429
# NHL:2 W:64 LR:0.01 BS:32 DR:0.0 L2:0.0001	0.7407
# NHL:2 W:32 LR:0.01 BS:32 DR:0.2 L2:0.0  	0.7386
# NHL:2 W:32 LR:0.01 BS:32 DR:0.1 L2:0.0001	0.7350
# NHL:2 W:128 LR:0.01 BS:32 DR:0.4 L2:0.0 	0.7350
# TRY 10/10 | NHL:4 W:128 LR:0.001 BS:128 DR:0.3 L2:0.001	0.7350
# NHL:2 W:64 LR:0.01 BS:32 DR:0.3 L2:0.0001	0.7343
# NHL:2 W:32 LR:0.01 BS:32 DR:0.0 L2:0.001	0.7336
# NHL:2 W:128 LR:0.01 BS:32 DR:0.0 L2:0.0001	0.7321
# NHL:2 W:32 LR:0.01 BS:32 DR:0.1 L2:0.001	0.7321
# NHL:2 W:32 LR:0.01 BS:32 DR:0.3 L2:0.0001	0.7314
# NHL:2 W:128 LR:0.01 BS:32 DR:0.0 L2:0.001	0.7279
# L2 64:0.01 32:0.01 + Dropout 64:0.0 32:0.1	0.7264
# NHL:2 W:32 LR:0.01 BS:32 DR:0.4 L2:0.0001	0.7221
# NHL:2 W:256 LR:0.01 BS:32 DR:0.0 L2:0.0 	0.7207
# NHL:2 W:32 LR:0.01 BS:32 DR:0.2 L2:0.001	0.7207
# NHL:2 W:256 LR:0.01 BS:32 DR:0.3 L2:0.0 	0.7200
# NHL:2 W:32 LR:0.01 BS:32 DR:0.4 L2:0.0  	0.7129
# NHL:2 W:128 LR:0.01 BS:32 DR:0.3 L2:0.0001	0.7121
# L2 64:1e-2 32:1e-2                      	0.7086
# NHL:2 W:64 LR:0.01 BS:32 DR:0.4 L2:0.0001	0.7071
# NHL:2 W:256 LR:0.01 BS:32 DR:0.2 L2:0.0 	0.7036
# NHL:2 W:64 LR:0.01 BS:32 DR:0.1 L2:0.001	0.7021
# NHL:2 W:256 LR:0.01 BS:32 DR:0.0 L2:0.001	0.7014
# NHL:2 W:64 LR:0.01 BS:32 DR:0.3 L2:0.001	0.7000
# L2 64:0.01 32:0.01 + Dropout 64:0.1 32:0.2	0.6964
# NHL:2 W:32 LR:0.01 BS:32 DR:0.4 L2:0.001	0.6964
# NHL:2 W:128 LR:0.01 BS:32 DR:0.1 L2:0.0001	0.6957
# NHL:2 W:128 LR:0.01 BS:32 DR:0.2 L2:0.0001	0.6957
# NHL:2 W:64 LR:0.01 BS:32 DR:0.2 L2:0.001	0.6957
# L2 64:0.01 32:0.01 + Dropout 64:0.1 32:0.3	0.6936
# NHL:2 W:128 LR:0.01 BS:32 DR:0.1 L2:0.001	0.6893
# Learning Rate 0.00001                   	0.6871
# NHL:2 W:32 LR:0.01 BS:32 DR:0.0 L2:0.01 	0.6821
# NHL:2 W:128 LR:0.01 BS:32 DR:0.0 L2:0.01	0.6800
# NHL:2 W:64 LR:0.01 BS:32 DR:0.4 L2:0.001	0.6771
# NHL:2 W:32 LR:0.01 BS:32 DR:0.3 L2:0.001	0.6757
# NHL:2 W:64 LR:0.01 BS:32 DR:0.0 L2:0.01 	0.6750
# NHL:2 W:32 LR:0.01 BS:32 DR:0.2 L2:0.01 	0.6750
# NHL:2 W:32 LR:0.01 BS:32 DR:0.3 L2:0.01 	0.6743
# NHL:2 W:256 LR:0.01 BS:32 DR:0.4 L2:0.0001	0.6743
# NHL:2 W:256 LR:0.01 BS:32 DR:0.0 L2:0.0001	0.6736
# NHL:2 W:256 LR:0.01 BS:32 DR:0.4 L2:0.0 	0.6729
# NHL:2 W:128 LR:0.01 BS:32 DR:0.4 L2:0.0001	0.6707
# NHL:2 W:128 LR:0.01 BS:32 DR:0.2 L2:0.001	0.6700
# NHL:2 W:128 LR:0.01 BS:32 DR:0.4 L2:0.001	0.6679
# NHL:2 W:64 LR:0.01 BS:32 DR:0.2 L2:0.01 	0.6643
# NHL:2 W:128 LR:0.01 BS:32 DR:0.3 L2:0.001	0.6614
# NHL:2 W:256 LR:0.01 BS:32 DR:0.0 L2:0.01	0.6607
# NHL:2 W:256 LR:0.01 BS:32 DR:0.1 L2:0.001	0.6593
# NHL:2 W:32 LR:0.01 BS:32 DR:0.1 L2:0.01 	0.6571
# NHL:2 W:256 LR:0.01 BS:32 DR:0.1 L2:0.0001	0.6529
# NHL:2 W:256 LR:0.01 BS:32 DR:0.3 L2:0.001	0.6507
# NHL:2 W:64 LR:0.01 BS:32 DR:0.3 L2:0.01 	0.6450
# NHL:2 W:256 LR:0.01 BS:32 DR:0.2 L2:0.0001	0.6436
# NHL:2 W:256 LR:0.01 BS:32 DR:0.1 L2:0.01	0.6421
# NHL:2 W:128 LR:0.01 BS:32 DR:0.1 L2:0.01	0.6400
# NHL:2 W:256 LR:0.01 BS:32 DR:0.3 L2:0.0001	0.6400
# NHL:2 W:64 LR:0.01 BS:32 DR:0.1 L2:0.01 	0.6379
# NHL:2 W:256 LR:0.01 BS:32 DR:0.2 L2:0.001	0.6314
# NHL:2 W:256 LR:0.01 BS:32 DR:0.4 L2:0.001	0.6293
# NHL:2 W:128 LR:0.01 BS:32 DR:0.2 L2:0.01	0.6171
# NHL:2 W:128 LR:0.01 BS:32 DR:0.3 L2:0.01	0.6136
# NHL:2 W:256 LR:0.01 BS:32 DR:0.2 L2:0.01	0.6021
# NHL:2 W:256 LR:0.01 BS:32 DR:0.3 L2:0.01	0.5764

# %% [markdown]
# ## Reflection Questions (ungraded)
#
# It would be a great idea to think through your answers to these questions, then give ChatGPT (or other AI tool) a PDF of your
# homework, and **discuss** (not just ask) these.
#
# 1. Activation Functions:
#
#     - Why do you think one activation function worked better than the others for this task?
#
#     - How might this choice differ for deeper or wider networks?
#
# 2. Learning Rate:
#
#     - Would a much smaller learning rate (with many more epochs) likely produce better accuracy?
#
#     - When is it worth training longer with a smaller step size, and when is it unnecessary?
#
# 3. Dropout vs. L2:
#
#     - Which form of regularization — dropout or L2 — gave better results in your experiments?
#
#     - Why might one method be more effective in this setting?
#
# 4. Combining Dropout and L2:
#
#     - Why might the combination of dropout and L2 sometimes perform worse than using one method alone?
#
#     - What does this tell you about the balance between bias and variance in regularization?
#
# 5. Best Model:
#
#     - When you designed your best model, what trade-offs did you notice between model complexity, training stability, and generalization?
#
#     - Did learning rate scheduling (if you tried it) improve results? Why might it help?
